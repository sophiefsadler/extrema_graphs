# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = RosenbrockMax2d
funMn = RosenbrockMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.75, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Rosenbrock_2d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  8
# Total number of points: 224
# Done.
# Scaling data...
# Done.
# Perform MDS...
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Done.
# array([[ 4.80391169e-01,  3.88053555e-01],
#        [-5.00909774e-01,  5.88557450e-01],
#        [ 1.36646282e-01, -2.82777092e-02],
#        [ 1.48614867e-01, -4.12572731e-01],
#        [-2.39414171e-01, -4.84487457e-01],
#        [-1.00575536e-02,  2.22989097e-02],
#        [ 1.71401774e-02,  5.81549470e-02],
#        [-8.39681652e-02, -1.09614287e-01],
#        [-3.91073699e-01,  5.67159813e-01],
#        [-2.80978766e-01,  5.45487419e-01],
#        [-1.71287076e-01,  5.23228234e-01],
#        [-6.21997812e-02,  5.00542697e-01],
#        [ 4.65541781e-02,  4.77750653e-01],
#        [ 1.55213517e-01,  4.54995023e-01],
# ...

# %%
funMx = RosenbrockMax3d
funMn = RosenbrockMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.75, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Rosenbrock_3d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  9
# Total number of points: 281
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-5.98988386e-01,  6.29766201e-01],
#        [ 1.37864648e-01,  9.24283981e-01],
#        [ 7.55293622e-01,  3.08079244e-01],
#        [ 6.62007077e-01, -3.34643052e-01],
#        [-4.03450420e-01, -4.21527119e-01],
#        [-5.09155317e-02, -5.39612472e-02],
#        [-9.85854947e-02, -3.01242128e-01],
#        [ 3.07262195e-02, -1.38215715e-01],
#        [-2.51307106e-01, -5.56276869e-01],
#        [ 7.06054738e-02,  8.70963628e-01],
#        [-4.08241018e-03,  8.23451093e-01],
#        [-8.12743751e-02,  7.81057376e-01],
#        [-1.61259340e-01,  7.43911107e-01],
#        [-2.44036398e-01,  7.11928741e-01],
#        [-3.29761495e-01,  6.84794348e-01],
#        [-4.18534990e-01,  6.61826811e-01],
#        [-5.09390630e-01,  6.42660896e-01],
# ...

# %%
funMx = RosenbrockMax5d
funMn = RosenbrockMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.75, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Rosenbrock_5d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  11
# Total number of points: 419
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[ 6.88839400e-01,  6.88063676e-01],
#        [ 1.23423469e-01,  9.58654687e-01],
#        [-3.70828031e-01, -7.30478456e-01],
#        [-8.41202113e-01,  5.80689042e-01],
#        [-9.95528086e-01, -6.23146021e-02],
#        [-7.36146350e-01, -5.72825059e-01],
#        [ 2.37572541e-03,  1.01616739e+00],
#        [-1.53589256e-01,  9.17131759e-01],
#        [ 4.00628893e-01, -8.90283209e-01],
#        [ 5.83543199e-01, -5.23483542e-01],
#        [ 4.99944763e-01, -9.81960686e-01],
#        [ 2.32811891e-01,  7.95994756e-01],
#        [ 2.74375081e-01,  7.03166843e-01],
#        [ 3.28919581e-01,  6.51847403e-01],
#        [ 3.85843561e-01,  6.30538307e-01],
#        [ 4.49769882e-01,  6.23166099e-01],
#        [ 5.08201886e-01,  6.29071431e-01],
# ...
