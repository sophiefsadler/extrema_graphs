# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = RastriginMax2d
funMn = RastriginMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=20000, nb_points=10, 
               radius_percentage=0.08, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  132
# Total number of points: 2516
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.94036994, -0.5601558 ],
#        [-3.02294785, -4.48982756],
#        [ 0.1496892 ,  3.39499232],
#        ...,
#        [ 1.66127467,  3.55692835],
#        [ 1.66391787,  3.66859064],
#        [ 1.66655906,  3.78025287]])

# %%
funMx = RastriginMax3d
funMn = RastriginMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=30000, nb_points=10, 
               radius_percentage=0.08, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  246
# Total number of points: 4670
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[ 1.00433919, -0.53664759],
#        [-0.23870268, -4.55727298],
#        [-1.86556714, -1.17385033],
#        ...,
#        [-1.37481028, -3.8470253 ],
#        [-1.4788225 , -3.82503673],
#        [-1.58377468, -3.80284112]])

# %%
funMx = RastriginMax5d
funMn = RastriginMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.08, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  465
# Total number of points: 7265
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-4.57908712, -1.81906085],
#        [ 0.93252171,  1.09079744],
#        [ 5.05320336, -1.28175534],
#        ...,
#        [-8.22221435,  6.00648216],
#        [-8.24232631,  5.92263416],
#        [-8.26233599,  5.84259412]])
