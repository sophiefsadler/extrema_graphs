# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = RastriginMax2d
funMn = RastriginMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=20000, nb_points=10, 
               radius_percentage=0.08, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Rastrigin_2d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  123
# Total number of points: 2371
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# array([[ 2.95608779,  2.06324693],
#        [ 0.09341543, -0.93358118],
#        [ 2.41896996,  2.91331843],
#        ...,
#        [-1.52940839,  2.55835353],
#        [-1.47039389,  2.46487842],
#        [-1.41137831,  2.37140398]])

# %%
funMx = RastriginMax3d
funMn = RastriginMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=30000, nb_points=10, 
               radius_percentage=0.08, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Rastrigin_3d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  224
# Total number of points: 3936
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[ 3.52877958, -5.90317804],
#        [-5.26782307,  4.21609023],
#        [ 1.93371994,  4.15616227],
#        ...,
#        [ 4.55442851,  0.07971529],
#        [ 4.48775499,  0.12089351],
#        [ 4.42546191,  0.16095204]])

# %%
funMx = RastriginMax5d
funMn = RastriginMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.08, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Rastrigin_5d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  455
# Total number of points: 5575
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-8.08239031, -3.24109948],
#        [-2.45370514,  7.21464995],
#        [-1.74213865, -5.80151939],
#        ...,
#        [ 0.32041895, -2.79139189],
#        [ 0.47112678, -2.75276235],
#        [ 0.62050877, -2.72038914]])
