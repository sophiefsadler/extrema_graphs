# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = AckleyMax2d
funMn = AckleyMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=20000, nb_points=10, 
               radius_percentage=0.05, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  141
# Total number of points: 3125
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.07417428,  0.21583895],
#        [-0.03227024,  0.30587146],
#        [-0.17512741, -0.37185334],
#        ...,
#        [-0.01147726,  0.57929839],
#        [-0.01000785,  0.57897935],
#        [-0.00853749,  0.57866119]])
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Computer Modern Serif

# %%
funMx = AckleyMax3d
funMn = AckleyMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=30000, nb_points=10, 
               radius_percentage=0.05, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  224
# Total number of points: 3248
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.44650728, -0.04387387],
#        [-0.78585521, -0.54061211],
#        [-0.46028873,  0.00342098],
#        ...,
#        [ 0.38046184,  0.70784449],
#        [ 0.37898422,  0.70786888],
#        [ 0.37751947,  0.70790129]])
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
funMx = AckleyMax5d
funMn = AckleyMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.05, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  503
# Total number of points: 5511
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[ 0.14955327,  0.26375796],
#        [ 0.3647261 ,  0.98704796],
#        [ 0.31666412,  0.96996958],
#        ...,
#        [-0.68946081, -0.09199698],
#        [-0.68874987, -0.08954374],
#        [-0.6880529 , -0.08708102]])
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
