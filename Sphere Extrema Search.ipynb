# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = SphereMax2d
funMn = SphereMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=20000, nb_points=30, 
               radius_percentage=0.75, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Sphere_2d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  5
# Total number of points: 229
# Done.
# Scaling data...
# Done.
# Perform MDS...
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Done.
# array([[ 2.16158901e+00,  6.91115850e+00],
#        [ 6.88868591e+00, -2.22972473e+00],
#        [-6.91132234e+00,  2.16027635e+00],
#        [-2.16400971e+00, -6.90936035e+00],
#        [-6.37317453e-04,  1.97996283e-03],
#        [ 6.74184942e+00, -1.86760606e+00],
#        [ 6.58033537e+00, -1.54887331e+00],
#        [ 6.41593155e+00, -1.24138608e+00],
#        [ 6.25354303e+00, -9.24836652e-01],
#        [ 6.09191316e+00, -6.02051363e-01],
#        [ 5.92842154e+00, -2.89166868e-01],
#        [ 5.76495906e+00,  2.41119540e-02],
#        [ 5.60145309e+00,  3.37126748e-01],
#        [ 5.43794265e+00,  6.49626669e-01],
# ...

# %%
funMx = SphereMax3d
funMn = SphereMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=30000, nb_points=10, 
               radius_percentage=0.75, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Sphere_3d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  9
# Total number of points: 169
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-6.40236328e+00,  6.48444748e+00],
#        [-2.92916418e+00, -8.65813364e+00],
#        [ 8.65212911e+00, -2.38726181e+00],
#        [ 3.13690941e+00,  8.61103297e+00],
#        [ 6.36210817e+00, -6.51877192e+00],
#        [ 6.21489421e+00,  6.44530109e+00],
#        [-6.38946665e+00, -6.22954984e+00],
#        [-8.62065574e+00,  2.51230289e+00],
#        [ 1.17887823e-03, -1.04037432e-02],
#        [ 2.01664443e+00,  8.24246598e+00],
#        [ 9.64156495e-01,  7.88609140e+00],
#        [-8.38106189e-02,  7.56714003e+00],
#        [-1.13753479e+00,  7.28196117e+00],
#        [-2.19295210e+00,  7.03059889e+00],
#        [-3.24352970e+00,  6.81608266e+00],
#        [-4.27900157e+00,  6.65109946e+00],
#        [-5.30431467e+00,  6.55878945e+00],
# ...

# %%
funMx = SphereMax5d
funMn = SphereMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.75, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Sphere_5d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  33
# Total number of points: 2209
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[  7.25666835,   9.61552406],
#        [-11.48475276,  -4.65491545],
#        [ -3.95611288,  11.7298496 ],
#        ...,
#        [ -4.39110044,  -2.20207262],
#        [ -6.03020797,  -2.71615938],
#        [ -8.92022105,  -3.52055121]])

# %%
funMx = SphereMax10d
funMn = SphereMin10d
extrema_search(funMx, funMn, number_of_fitness_evaluations=100000, nb_points=10, 
               radius_percentage=0.4, nsph_points=1000, do_scaling=False, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Sphere_10d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  263
# Total number of points: 4423
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[ -9.12372787,  12.60961079],
#        [  9.76471988, -12.32260651],
#        [ -4.55332647,  14.02398378],
#        ...,
#        [ 11.19528979,   9.50440305],
#        [ 11.29388654,  10.46996589],
#        [ 11.3869496 ,  11.40193393]])
