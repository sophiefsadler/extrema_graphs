# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = AckleyMax2d
funMn = AckleyMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=20000, nb_points=10, 
               radius_percentage=0.05, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Ackley_2d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  119
# Total number of points: 3223
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# array([[ 0.39758884, -0.18106713],
#        [-0.75115541, -0.02180537],
#        [ 0.16614845,  0.33833303],
#        ...,
#        [ 0.19862785,  0.12116413],
#        [ 0.19944626,  0.1233826 ],
#        [ 0.20026467,  0.12560108]])

# %%
funMx = AckleyMax3d
funMn = AckleyMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=30000, nb_points=10, 
               radius_percentage=0.05, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Ackley_3d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  235
# Total number of points: 6059
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.19437726, -0.85958205],
#        [ 0.04869703, -0.75531097],
#        [ 0.03609731, -0.67577592],
#        ...,
#        [ 0.23650967,  0.36757239],
#        [ 0.23322655,  0.37221214],
#        [ 0.2301276 ,  0.37697677]])

# %%
funMx = AckleyMax5d
funMn = AckleyMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.05, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Ackley_5d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  428
# Total number of points: 9596
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# array([[ 0.4262328 ,  0.90819459],
#        [ 0.77078839, -0.51652407],
#        [ 0.79936153, -0.55390409],
#        ...,
#        [-0.09373517,  0.04173086],
#        [-0.09559537,  0.03928293],
#        [-0.09774097,  0.03665644]])
