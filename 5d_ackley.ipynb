# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy import optimize
from matplotlib import cm
import matplotlib.pyplot as plt
import random
import networkx as nx
from scipy.spatial import distance
from scipy import interpolate
from sklearn.manifold import MDS
from sklearn.preprocessing import MinMaxScaler
from pynmmso import Nmmso

# %%
def ackley(x, y, z, a, b):
    sum_squares = x**2 + y**2 + z**2 + a**2 + b**2
    sum_cos = np.cos(2*np.pi*x) + np.cos(2*np.pi*y) + np.cos(2*np.pi*z) + np.cos(2*np.pi*a) + np.cos(2*np.pi*b)
    exp_1 = -0.2*np.sqrt((1/5)*sum_squares)
    exp_2 = (1/5)*sum_cos
    return -20*np.exp(exp_1) - np.exp(exp_2) + 20 + np.e

# %%
class AckleyMax:
    @staticmethod
    def fitness(params):
        x = params[0]
        y = params[1]
        z = params[2]
        a = params[3]
        b = params[4]
        sum_squares = x**2 + y**2 + z**2 + a**2 + b**2
        sum_cos = np.cos(2*np.pi*x) + np.cos(2*np.pi*y) + np.cos(2*np.pi*z) + np.cos(2*np.pi*a) + np.cos(2*np.pi*b)
        exp_1 = -0.2*np.sqrt((1/5)*sum_squares)
        exp_2 = (1/5)*sum_cos
        return -20*np.exp(exp_1) - np.exp(exp_2) + 20 + np.e

    @staticmethod
    def get_bounds():
        return [-32.768, -32.768, -32.768, -32.768, -32.768], [32.768, 32.768, 32.768, 32.768, 32.768]

class AckleyMin:
    @staticmethod
    def fitness(params):
        x = params[0]
        y = params[1]
        z = params[2]
        a = params[3]
        b = params[4]
        sum_squares = x**2 + y**2 + z**2 + a**2 + b**2
        sum_cos = np.cos(2*np.pi*x) + np.cos(2*np.pi*y) + np.cos(2*np.pi*z) + np.cos(2*np.pi*a) + np.cos(2*np.pi*b)
        exp_1 = -0.2*np.sqrt((1/5)*sum_squares)
        exp_2 = (1/5)*sum_cos
        return -(-20*np.exp(exp_1) - np.exp(exp_2) + 20 + np.e)

    @staticmethod
    def get_bounds():
        return [-32.768, -32.768, -32.768, -32.768, -32.768], [32.768, 32.768, 32.768, 32.768, 32.768]

# %%
func_values_matching_optima = []

# %%
maxs_found = []

number_of_fitness_evaluations = 10000

nmmso = Nmmso(AckleyMax())
my_result = nmmso.run(number_of_fitness_evaluations)
for mode_result in my_result:
    maxs_found.append(mode_result.location)
    func_values_matching_optima.append(mode_result.value)

# %%
print('The {0} maxima found are:'.format(len(maxs_found)))
np.around(maxs_found, 2)
# Out:
# The 110 maxima found are:
# array([[ 30.3 ,   1.57, -32.56, -17.59,  31.33],
#        [ 31.5 , -17.43,  27.51,  27.54,  10.56],
#        [ 24.51,  29.47,  13.46, -19.57,  32.53],
#        [-16.57,  -1.53, -31.4 , -32.66, -21.4 ],
#        [ -4.39, -26.45,   7.52, -31.55, -31.62],
#        [ 28.47,  15.44, -21.6 , -31.73,  28.5 ],
#        [ -4.38, -23.41, -31.31, -27.51, -10.49],
#        [-28.6 ,  31.52,  -4.47, -30.51,  -1.53],
#        [-30.3 , -14.42,  -1.43,  20.42, -25.44],
#        [ -4.65,  27.43, -23.33,  19.34, -30.65],
#        [ 30.49,  26.35, -20.67, -10.47,  20.5 ],
#        [-16.49,  23.36,  -0.42, -20.39,  31.46],
#        [-32.53,  27.51,  20.26, -23.41, -28.49],
#        [ 20.46, -30.47, -14.51, -30.69, -18.47],
#        [ 31.45, -29.36,  -7.49,  29.47,  22.48],
#        [ 24.48, -14.4 ,  -3.44, -30.51,  28.49],
#        [ 28.46, -31.52, -32.61, -23.61, -32.54],
#        [ 15.69, -17.44, -27.6 ,  29.45,  30.41],
#        [ 32.54, -28.36, -14.49, -29.31,  32.38],
#        [ 31.45,  32.53, -28.42, -28.71,  22.48],
#        [-21.47,  -1.53, -32.36, -32.61, -28.5 ],
#        [-29.66,  31.61,  -6.35,  32.47, -22.27],
#        [ 31.69,  32.59,  25.35, -14.5 , -17.57],
#        [ 27.59, -29.52,  17.44, -14.49, -29.68],
#        [-24.5 ,  32.53, -28.42, -28.71,  15.53],
#        [-31.58,  19.72,  31.56, -24.52,  31.36],
#        [ 29.5 , -28.5 , -10.46,  32.53,  -6.61],
#        [-32.57, -31.65,  15.28, -31.51,  10.41],
#        [-30.69, -15.57,   0.37,  21.13, -31.38],
#        [-28.54, -28.5 , -31.47, -31.44,  -6.61],
#        [ 31.52,  14.52,  -9.48, -32.69,  32.58],
#        [ 26.71,  32.55,  -3.47,  28.47, -22.83],
#        [ 29.5 ,  23.42, -31.51,   4.54, -31.52],
#        [ 32.53, -32.57,  19.69,  21.79, -27.43],
#        [ 29.54,  31.49,  28.49, -29.29,  14.39],
#        [ 27.66,  -1.53,  -3.45, -32.66, -23.44],
#        [ 31.66, -32.57,  -7.59,  19.44, -17.48],
#        [ 31.66,  32.59,  -7.58,  19.44, -17.51],
#        [-19.45,  32.66,  -1.25, -32.33,  32.63],
#        [ 23.49, -23.62, -22.53, -14.55,  12.49],
#        [ 31.46, -22.5 ,  -7.49, -32.51,  22.47],
#        [ 31.55, -31.52, -31.75, -19.78, -30.43],
#        [ 20.47,  31.38, -29.55, -21.73,  19.37],
#        [ 32.4 , -14.42,  -6.56,  20.42, -32.5 ],
#        [ 28.58,  14.51,  -9.59, -31.72,  26.44],
#        [-32.5 ,  32.67,  29.37, -14.54,  12.57],
#        [-32.65, -32.45, -28.32,  16.54, -32.49],
#        [ 27.66, -11.41, -31.47, -31.44,  30.6 ],
#        [-32.41,  31.49,  30.48, -17.43,  29.55],
#        [ 31.38, -14.63,  -3.48, -31.45,  19.53],
#        [-28.6 ,  31.49,  -4.17, -25.47,  -1.32],
#        [ 32.63,  23.35, -31.46,  15.55, -22.38],
#        [ -6.48, -30.71,  24.53, -32.5 ,  30.72],
#        [ 17.38, -23.82, -17.67, -12.53, -27.97],
#        [-32.46,  27.5 , -18.31, -20.63,  31.47],
#        [ 23.56, -23.45, -14.63, -31.55, -18.61],
#        [ 28.37,  32.5 ,  -3.4 ,  27.53, -24.72],
#        [-27.64, -16.55, -24.53, -28.53,  14.46],
#        [-32.37, -18.58,  -0.53,  21.53, -32.5 ],
#        [-31.79, -32.49,  14.8 , -32.36,  12.34],
#        [ 31.46,  29.45,  30.39, -24.54,   8.42],
#        [-16.51,  27.52,  -0.64, -20.49,  32.61],
#        [ 27.57,  31.52, -10.52,  25.56,  31.55],
#        [ 30.65, -16.48,  -4.41, -32.54, -27.53],
#        [ -5.46, -30.45,  21.59, -30.59,   8.53],
#        [ 31.39, -12.44,   5.68,  21.43, -30.41],
#        [ 32.5 , -25.46, -20.58,  30.5 , -30.55],
#        [-26.53, -21.47, -24.41,  10.48, -30.4 ],
#        [ 29.5 ,  31.58,   9.74, -23.46,  30.44],
#        [-32.53,  22.42,  30.39, -31.49,  31.5 ],
#        [-32.64, -30.55,  14.51, -29.48,   3.57],
#        [ 28.52,  32.51,  -3.45,  27.53, -23.44],
#        [-32.41,  29.45, -14.49,  -9.61,  -9.64],
#        [ 29.52,  31.54,  -2.48,  22.58, -32.49],
#        [-32.46,  32.58, -22.53, -14.52,  12.48],
#        [-30.36, -22.42, -27.69,   9.36, -31.73],
#        [ 32.46,  32.64,  -2.57,  19.56, -21.48],
#        [-28.49, -32.57, -21.7 , -17.53,  30.5 ],
#        [ 32.32, -13.53,   4.46,  24.53, -32.67],
#        [ 32.52, -29.46, -14.51, -29.52,  32.52],
#        [-25.3 , -25.38,  14.54, -30.6 ,  22.54],
#        [ 26.47,  31.49,   4.44, -18.52,  31.46],
#        [ 24.63,  26.53,  28.53,  32.36,  -8.38],
#        [-32.46,  32.62,  -1.56, -31.53,  -3.52],
#        [ 23.44, -29.36, -14.49,  29.47, -18.52],
#        [ 29.37,  20.68,   9.51, -31.46,  26.55],
#        [ 28.52,  31.47,  -0.55, -20.51,  32.51],
#        [ -6.62, -32.46,  -6.58,  25.39, -31.42],
#        [-31.5 ,  31.38, -20.44, -14.53,  12.45],
#        [-24.52,  31.58,  -9.37, -12.52,  -7.51],
#        [ 16.47, -17.43, -21.51,  27.54,  28.59],
#        [ 32.4 ,  15.21,  -6.57, -24.47,  17.48],
#        [-31.55,  32.48,   9.61, -19.57,  -6.46],
#        [-32.49,  32.64, -22.47, -14.54,  32.58],
#        [ -4.42,  32.67,  -7.55,  19.48, -19.44],
#        [-16.42,  30.59,  -0.56, -31.54,  32.66],
#        [ 24.53, -14.39,  14.51,  30.6 ,  19.51],
#        [ 32.49, -26.49, -16.55, -31.52,  20.51],
#        [ 31.42, -14.42,  -2.5 , -32.48, -30.56],
#        [ 32.4 , -14.42,  -6.56,  20.42,  17.48],
#        [-16.56,  21.62,  32.76,  26.47, -18.72],
#        [ 28.57,  25.53, -32.44, -14.49, -31.45],
#        [-30.48, -23.37,  21.58, -29.54, -28.29],
#        [ 32.59,  32.72,  -9.56,  18.44, -26.65],
#        [ 32.52, -29.59, -14.51,  19.43, -24.61],
#        [-28.54, -28.5 , -10.46,  32.51,  -6.61],
#        [-26.52, -26.46, -23.49,  32.37,  -4.49],
#        [ 27.66, -11.41,  -3.45,  27.53, -23.44],
#        [ 32.62,  32.4 ,  -8.61,  18.33, -23.67],
#        [ 29.83,  21.61,   9.95,  -5.56,  30.53]])

# %%
mins_found = []

number_of_fitness_evaluations = 10000

nmmso = Nmmso(AckleyMin())
my_result = nmmso.run(number_of_fitness_evaluations)
for mode_result in my_result:
    mins_found.append(mode_result.location)
    func_values_matching_optima.append(-mode_result.value)

# %%
print('The {0} minima found are:'.format(len(mins_found)))
np.around(mins_found, 2)
# Out:
# The 44 minima found are:
# array([[-0.97, -0.98, -0.01,  1.94, -0.97],
#        [-0.94, -0.95,  0.01,  0.96, -0.02],
#        [-0.97, -0.02, -0.  ,  1.93, -0.  ],
#        [-0.96,  0.02,  0.96,  0.97, -0.96],
#        [ 0.  , -0.97,  0.98,  0.97, -1.95],
#        [ 0.  , -0.97,  0.96,  0.96, -0.96],
#        [-0.96, -0.96,  0.  ,  0.96, -0.97],
#        [-0.01, -0.95, -0.01,  0.94, -0.  ],
#        [-0.  , -0.97,  0.98, -0.01, -1.95],
#        [-0.98, -0.98,  0.98,  1.95, -0.98],
#        [ 0.  , -0.97,  0.96,  2.96, -0.  ],
#        [ 0.  , -0.01,  0.98,  1.94, -0.97],
#        [-0.96, -0.02,  0.01,  1.94, -1.94],
#        [-0.96, -0.98, -0.01,  0.99, -1.97],
#        [-0.98, -0.98, -0.  ,  1.95, -0.  ],
#        [-0.98, -0.98,  0.98,  2.94, -0.97],
#        [-0.99, -0.98,  0.  ,  2.94, -1.97],
#        [-0.95, -0.96,  0.96, -0.  , -0.  ],
#        [-0.98, -0.97,  0.98,  0.98, -1.94],
#        [ 0.  , -0.95,  0.95, -0.  ,  0.  ],
#        [ 0.  , -0.97, -0.01,  2.94, -0.99],
#        [ 0.  , -0.98,  0.98,  1.96, -1.96],
#        [-0.97, -0.97,  0.98, -0.  , -1.95],
#        [-0.01, -0.97,  0.  ,  1.93,  0.01],
#        [-0.02, -0.  ,  0.96, -0.01, -0.95],
#        [ 0.  , -0.97,  0.96,  2.96, -1.96],
#        [-0.98, -0.98, -0.98,  2.96, -1.96],
#        [-0.97, -0.97,  0.97,  0.97, -0.97],
#        [ 0.  , -0.96,  0.95,  0.  , -0.96],
#        [-0.99, -0.97,  0.  ,  2.94, -0.97],
#        [-0.  ,  0.  ,  0.96,  0.96, -0.96],
#        [-0.92,  0.01,  0.02, -0.  , -0.02],
#        [-0.97, -0.96,  0.97,  0.  , -0.96],
#        [ 0.07, -0.03,  0.01,  1.04, -2.04],
#        [-0.01, -0.95, -0.  ,  0.  , -0.95],
#        [-0.98, -0.98,  0.98,  1.95,  0.98],
#        [-0.98, -0.98, -0.  ,  2.94,  0.  ],
#        [ 0.  , -0.97,  0.  ,  1.94, -0.97],
#        [-0.01,  0.01, -0.01, -0.  , -0.92],
#        [-0.  , -0.97,  0.97,  1.95, -0.97],
#        [-1.  , -0.97, -0.98,  0.98, -1.98],
#        [-0.96, -0.96, -0.  ,  0.  , -0.96],
#        [-0.98, -0.97,  0.97,  0.96, -0.01],
#        [-0.97, -0.97, -0.  ,  0.  , -1.94]])

# %%
optima = np.stack(mins_found + maxs_found, axis=0)

# %%
to_label = list(optima)
label_ind = [i for i in range(len(to_label))]

# %%
edges = []
for i in range(len(optima)):
    for j in range(len(optima)):
        if i != j:
            dist = distance.euclidean(optima[i, :], optima[j, :])
            if dist < 1:  ## Distance chosen arbitrarily
                if (min(i,j), max(i,j)) not in edges:
                    edges.append((i,j))

# %%
def intermediates(p1, p2, nb_points=50):
    x_spacing = (p2[0] - p1[0]) / (nb_points + 1)
    y_spacing = (p2[1] - p1[1]) / (nb_points + 1)
    z_spacing = (p2[2] - p1[2]) / (nb_points + 1)
    a_spacing = (p2[3] - p1[3]) / (nb_points + 1)
    b_spacing = (p2[4] - p1[4]) / (nb_points + 1)

    return [[p1[0] + i * x_spacing, p1[1] +  i * y_spacing, p1[2] +  i * z_spacing, p1[3] +  i * a_spacing, p1[4] +  i * b_spacing] 
            for i in range(1, nb_points+1)]

new_data = []
for i in range(len(optima)):
    new_data.append(optima[i,:])
for edge in edges:
    pos_node_1 = optima[edge[0], :]
    pos_node_2 = optima[edge[1], :]
    new_nodes = intermediates(pos_node_1, pos_node_2)
    to_label.append(new_nodes[9])
    to_label.append(new_nodes[19])
    to_label.append(new_nodes[29])
    to_label.append(new_nodes[39])
    label_ind += [len(new_data)+9, len(new_data)+19, len(new_data)+29, len(new_data)+39]
    for node in new_nodes:
        new_data.append(np.array(node))

# %%
scaler = MinMaxScaler()
new_data_scaled = scaler.fit_transform(new_data)

# %%
mds = MDS(2, random_state=0)
mds_new_data = mds.fit_transform(new_data_scaled)

# %%
G = nx.Graph()
G.add_nodes_from([i for i in range(len(new_data))])

# %%
x = mds_new_data[:, 0]
y = mds_new_data[:, 1]

pos = {i: [x[i], y[i]] for i in range(len(new_data))}

# %%
plt.rcParams['figure.figsize'] = [25, 15]

node_sizes = [500 for _ in range(154)] + [5 for _ in range(G.number_of_nodes() - 154)]

func_val_map = {i: ackley(new_data[i][0], new_data[i][1], new_data[i][2], new_data[i][3], new_data[i][4]) for i in range(len(new_data))}

values = [func_val_map[node] for node in G.nodes()]

fig, ax = plt.subplots()
nx.draw(G, pos=pos, ax=ax, node_size=node_sizes, node_color=values)
# for i, opt in enumerate(optima):
#     plt.annotate(str(np.around(opt, 2)), (x[i], y[i]), xytext=(x[i]+0.03, y[i]+0.03), size=8)
limits=plt.axis('on')
plt.show()
