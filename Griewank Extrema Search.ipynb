# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = GriewankMax2d
funMn = GriewankMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=20000, nb_points=10, 
               radius_percentage=0.25, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Griewank_2d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  13
# Total number of points: 93
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.14546786, -0.65831253],
#        [ 0.23029574,  0.22265492],
#        [ 0.66950354, -0.08141497],
#        [-0.28192192, -0.14051327],
#        [ 0.08858659,  0.73708577],
#        [-0.31800697,  0.44530225],
#        [ 0.26030832, -0.36831139],
#        [-0.43030971, -0.25327947],
#        [ 0.00175777, -0.54822625],
#        [ 0.51625897, -0.1864348 ],
#        [-0.57068999,  0.26622231],
#        [-0.02414382,  0.04138741],
#        [-0.06177609,  0.62721743],
#        [-0.01531352, -0.56024547],
#        [-0.03242998, -0.57224354],
#        [-0.04959367, -0.58421801],
#        [-0.06679262, -0.5961704 ],
#        [-0.08404229, -0.60809475],
#        [-0.1013107 , -0.61999951],
#        [-0.11857846, -0.63189236],
#        [-0.13576891, -0.6438143 ],
# ...

# %%
funMx = GriewankMax3d
funMn = GriewankMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=30000, nb_points=10, 
               radius_percentage=0.25, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Griewank_3d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  36
# Total number of points: 252
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[ 7.79448945e-01, -1.05292965e-01],
#        [ 3.12575336e-01, -3.57339828e-01],
#        [ 2.24964380e-02, -4.63974301e-02],
#        [ 1.09204164e-01,  7.75490114e-01],
#        [-7.60524153e-01,  1.95503340e-01],
#        [-3.06199206e-01,  3.68620546e-01],
#        [ 7.73997193e-01,  9.22152464e-02],
#        [-7.83665000e-01, -2.12367946e-03],
#        [-8.10309760e-02,  7.80600398e-01],
#        [-4.49315301e-02,  9.57511509e-02],
#        [-4.69086988e-01,  5.55060017e-01],
#        [ 5.22136528e-01,  4.90008765e-01],
#        [ 4.83947782e-01, -5.21087840e-01],
#        [-5.60731113e-01, -4.43855299e-01],
#        [-1.95759723e-01, -7.54059428e-01],
#        [-3.61011352e-01, -3.10731827e-01],
#        [-2.66822397e-03, -7.88072224e-01],
# ...

# %%
funMx = GriewankMax5d
funMn = GriewankMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.15, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Griewank_5d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  136
# Total number of points: 576
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.91323877, -0.2578718 ],
#        [ 0.10546604, -0.89874032],
#        [-0.0565555 ,  0.88700102],
#        ...,
#        [ 0.08823728, -0.58678655],
#        [ 0.08940221, -0.63631816],
#        [ 0.09093125, -0.70015169]])
