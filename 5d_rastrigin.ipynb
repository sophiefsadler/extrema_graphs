# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy import optimize
from matplotlib import cm
import matplotlib.pyplot as plt
import random
import networkx as nx
from scipy.spatial import distance
from scipy import interpolate
from sklearn.manifold import MDS
from sklearn.preprocessing import MinMaxScaler
from pynmmso import Nmmso

# %%
def rastrigin(x, y, z, a, b):
    sum_squares = x**2 + y**2 + z**2 + a**2 + b**2
    sum_cos = np.cos(2*np.pi*x) + np.cos(2*np.pi*y) + np.cos(2*np.pi*z) + np.cos(2*np.pi*a) + np.cos(2*np.pi*b)
    return 50 + sum_squares - 10*sum_cos

# %%
class RastriginMax:
    @staticmethod
    def fitness(params):
        x = params[0]
        y = params[1]
        z = params[2]
        a = params[3]
        b = params[4]
        sum_squares = x**2 + y**2 + z**2 + a**2 + b**2
        sum_cos = np.cos(2*np.pi*x) + np.cos(2*np.pi*y) + np.cos(2*np.pi*z) + np.cos(2*np.pi*a) + np.cos(2*np.pi*b)
        return 50 + sum_squares - 10*sum_cos

    @staticmethod
    def get_bounds():
        return [-5.12, -5.12, -5.12, -5.12, -5.12], [5.12, 5.12, 5.12, 5.12, 5.12]

class RastriginMin:
    @staticmethod
    def fitness(params):
        x = params[0]
        y = params[1]
        z = params[2]
        a = params[3]
        b = params[4]
        sum_squares = x**2 + y**2 + z**2 + a**2 + b**2
        sum_cos = np.cos(2*np.pi*x) + np.cos(2*np.pi*y) + np.cos(2*np.pi*z) + np.cos(2*np.pi*a) + np.cos(2*np.pi*b)
        return -(50 + sum_squares - 10*sum_cos)

    @staticmethod
    def get_bounds():
        return [-5.12, -5.12, -5.12, -5.12, -5.12], [5.12, 5.12, 5.12, 5.12, 5.12]

# %%
func_values_matching_optima = []

# %%
maxs_found = []

number_of_fitness_evaluations = 10000

nmmso = Nmmso(RastriginMax())
my_result = nmmso.run(number_of_fitness_evaluations)
for mode_result in my_result:
    maxs_found.append(mode_result.location)
    func_values_matching_optima.append(mode_result.value)

# %%
print('The {0} maxima found are:'.format(len(maxs_found)))
np.around(maxs_found, 2)
# Out:
# The 77 maxima found are:
# array([[ 3.48,  4.52, -0.47, -4.52,  4.5 ],
#        [-2.54,  4.52,  1.53,  1.5 , -2.5 ],
#        [ 4.47, -3.57,  2.37, -3.66, -3.63],
#        [ 3.53, -0.49,  4.55,  4.52, -4.56],
#        [ 2.41,  4.56,  1.58,  4.5 , -4.51],
#        [-4.54,  4.55,  4.52, -4.52, -4.61],
#        [-3.57,  4.5 , -4.51, -4.51,  4.53],
#        [-4.48, -4.57,  4.69,  2.47,  4.44],
#        [ 4.45, -4.51,  2.52, -4.54,  3.51],
#        [-3.56,  4.49,  4.49, -4.56,  4.53],
#        [-4.51, -2.64, -3.52,  2.44,  4.58],
#        [-4.52, -2.5 , -4.54,  4.5 ,  4.53],
#        [-4.52, -2.51, -4.54,  4.51, -4.49],
#        [-4.53, -1.45, -4.53,  4.54, -3.5 ],
#        [-4.52, -4.55, -4.55, -4.52, -3.48],
#        [-4.52,  3.52, -3.52, -1.47,  4.54],
#        [-0.48, -1.44,  4.5 , -4.54, -4.52],
#        [ 3.56,  4.48,  4.62,  4.51,  4.53],
#        [-4.54, -4.5 , -3.5 ,  4.58,  4.52],
#        [-4.69,  4.49,  4.5 ,  2.46,  4.52],
#        [ 3.54, -4.54,  4.61,  4.52,  4.5 ],
#        [-0.47, -0.55, -4.59, -4.53, -4.5 ],
#        [ 4.52, -0.54,  3.52,  4.52, -4.54],
#        [ 4.69, -4.53, -3.49,  3.94,  4.63],
#        [-4.69,  4.52, -4.54, -4.57,  4.62],
#        [-0.51, -1.49, -4.5 , -1.53, -4.52],
#        [-0.54, -1.48, -3.53,  4.5 , -4.53],
#        [ 4.52, -1.53, -4.53,  0.49, -1.51],
#        [ 3.55,  2.52,  2.59,  4.5 , -3.46],
#        [ 3.52, -4.55,  4.59, -0.53,  4.5 ],
#        [-2.45, -1.64,  1.56,  3.56,  2.66],
#        [ 4.45,  4.52, -4.53,  4.52, -4.61],
#        [-4.53,  4.52, -3.52, -1.46,  4.55],
#        [-2.45, -4.53,  1.56,  3.56,  4.63],
#        [ 2.56, -0.49,  4.51,  4.52, -4.57],
#        [-2.48, -2.53, -4.59, -3.5 , -3.52],
#        [-4.52,  2.51,  2.51, -1.52, -3.52],
#        [-1.62, -0.51,  4.51, -4.43, -4.48],
#        [-4.53,  3.5 , -3.53,  4.49,  4.5 ],
#        [-4.53,  0.5 ,  2.52,  1.49, -3.55],
#        [ 4.53,  4.53, -3.53,  4.52, -3.53],
#        [-4.52, -4.52, -4.52, -4.51,  4.52],
#        [-4.66,  4.53, -4.48,  4.52, -3.58],
#        [ 4.53, -4.53,  4.53,  4.52,  3.52],
#        [ 2.55,  4.61,  3.54,  1.43,  4.53],
#        [ 4.57,  4.54, -3.62, -4.53,  4.52],
#        [ 4.66,  4.65,  4.56, -4.41, -4.5 ],
#        [-2.53, -4.53, -4.5 ,  4.67, -4.57],
#        [ 3.51,  4.54,  4.57, -4.44, -4.54],
#        [-4.52,  4.52, -3.51, -4.53, -4.56],
#        [ 4.56,  4.5 ,  4.56,  1.6 ,  4.61],
#        [ 2.49,  3.51,  1.37, -1.68,  2.58],
#        [-0.48, -1.45, -4.53, -4.55, -3.49],
#        [-2.54,  4.57, -4.49, -4.52, -4.53],
#        [ 4.46,  4.72,  4.51, -4.62, -3.53],
#        [ 3.56, -4.52,  2.51, -0.5 , -4.51],
#        [ 4.52, -3.43, -3.45,  4.48,  4.54],
#        [-4.48,  3.55,  4.54,  4.54, -3.47],
#        [ 3.53,  4.52, -3.54, -4.51, -3.53],
#        [ 4.61,  4.57,  3.53,  4.62,  1.37],
#        [-4.37,  4.54,  4.65,  1.46, -3.52],
#        [-3.53, -4.48, -3.45,  4.46, -3.45],
#        [-1.41, -4.45, -3.69, -4.5 , -4.47],
#        [ 4.51,  4.52,  2.49,  3.46, -4.51],
#        [ 5.09, -1.54, -4.53,  1.47, -2.52],
#        [-4.57, -1.47, -3.46, -4.5 , -3.45],
#        [-2.51,  4.49, -0.49,  4.53,  4.51],
#        [ 2.51, -0.48,  4.58, -4.44, -4.48],
#        [ 4.51,  3.42, -4.49,  2.63,  2.61],
#        [ 4.68,  4.17,  2.58,  4.49, -3.51],
#        [ 4.51, -1.54, -4.53, -3.58, -2.43],
#        [-2.56,  3.54,  4.43, -4.43, -4.56],
#        [ 3.64, -3.48,  2.34, -3.42, -1.49],
#        [-4.51, -1.45, -4.53, -4.55, -3.49],
#        [ 4.53,  4.53, -3.52,  3.52, -3.52],
#        [-2.53, -4.53, -4.5 , -4.54,  3.51],
#        [-4.53,  4.52, -3.52, -4.54,  4.55]])

# %%
mins_found = []

number_of_fitness_evaluations = 10000

nmmso = Nmmso(RastriginMin())
my_result = nmmso.run(number_of_fitness_evaluations)
for mode_result in my_result:
    mins_found.append(mode_result.location)
    func_values_matching_optima.append(-mode_result.value)

# %%
print('The {0} minima found are:'.format(len(mins_found)))
np.around(mins_found, 2)
# Out:
# The 88 minima found are:
# array([[ 0.  ,  0.  , -0.  , -0.99, -1.  ],
#        [-0.93,  3.99,  2.  , -0.  , -2.96],
#        [ 1.94, -0.  , -0.01, -0.  , -1.04],
#        [ 0.04,  1.  , -0.03,  0.01,  1.99],
#        [ 1.9 , -0.16, -1.07,  2.73, -0.19],
#        [-0.03,  1.01, -0.02, -1.02,  1.97],
#        [-0.86,  1.  ,  3.06,  0.03, -2.06],
#        [-1.  ,  2.02,  3.99, -1.01, -1.  ],
#        [ 0.02,  0.01,  1.97,  0.02, -1.  ],
#        [ 4.92, -0.07, -0.93, -0.02,  2.98],
#        [-0.99,  3.99,  0.09,  0.06, -1.97],
#        [-0.04,  3.  ,  0.11, -1.08, -1.  ],
#        [-1.98, -1.01,  3.97, -2.68, -1.97],
#        [ 0.96,  0.05,  2.94, -0.02, -3.13],
#        [-0.02,  2.99, -0.05, -0.  , -2.98],
#        [-0.07,  2.94,  2.99,  3.01,  2.97],
#        [ 0.  , -0.07, -0.93, -0.01, -1.98],
#        [ 0.01,  4.  ,  1.98, -0.03, -2.  ],
#        [ 0.98,  3.02,  1.  , -0.95, -1.02],
#        [-1.04,  2.99,  0.01, -0.97, -1.02],
#        [ 3.05,  0.84,  3.  , -0.05, -0.97],
#        [-1.02,  3.03,  2.97,  0.  , -1.03],
#        [-0.  ,  0.99,  0.  , -0.02, -0.94],
#        [-0.03,  1.02,  1.98, -0.97,  0.03],
#        [ 0.99,  2.01,  2.98, -1.09, -0.98],
#        [ 0.99,  3.04,  2.88,  0.06, -0.99],
#        [ 0.99,  1.99,  3.97, -0.04, -1.  ],
#        [ 1.02,  4.02,  0.04, -0.  ,  2.  ],
#        [ 2.  ,  1.  , -0.99, -0.98,  1.92],
#        [-1.06,  2.97, -1.24, -1.11,  1.72],
#        [ 4.01, -0.05,  1.03, -1.94, -2.  ],
#        [ 0.01,  0.01,  0.02,  4.88,  1.99],
#        [-1.  , -0.01,  3.97, -0.  , -1.03],
#        [ 1.  ,  4.  ,  2.98, -0.05, -0.99],
#        [ 0.96,  0.05,  3.  , -0.05, -0.97],
#        [ 1.  ,  3.01,  0.  , -1.02, -1.99],
#        [-1.  ,  3.93,  0.01,  0.05, -1.  ],
#        [-0.99,  1.05,  2.02,  0.01,  0.07],
#        [ 1.01,  3.99,  1.98, -0.03, -0.98],
#        [ 0.  ,  1.01,  2.02, -0.96, -1.98],
#        [ 1.93,  3.97,  0.08,  0.02, -3.96],
#        [-1.89,  2.03,  0.03, -2.01, -1.05],
#        [ 0.01,  1.99,  1.99, -0.99, -0.99],
#        [-1.07,  2.99,  2.98,  0.  , -2.99],
#        [ 0.96,  1.97,  2.02,  0.12, -2.01],
#        [-0.99,  0.  ,  0.  ,  0.06, -1.  ],
#        [ 0.94,  0.97,  2.01, -0.01, -0.99],
#        [-0.01,  0.97,  1.98, -1.01, -0.99],
#        [ 0.99,  1.01,  3.02, -0.97, -1.97],
#        [-1.99,  2.98,  2.98, -1.01, -0.99],
#        [ 0.01,  1.99,  3.  , -0.99, -0.98],
#        [ 2.02,  2.98,  2.98, -0.99, -0.96],
#        [ 1.99,  1.96, -2.  , -1.  , -1.02],
#        [ 5.08,  0.03, -1.04,  0.21,  1.95],
#        [-0.98,  2.04,  2.95, -1.01, -0.98],
#        [-1.98,  1.98,  2.1 , -1.01, -0.99],
#        [-1.03,  2.12,  2.97,  0.04, -1.04],
#        [-1.95, -0.94, -0.21, -0.98,  0.78],
#        [ 3.05,  0.84,  0.98, -0.05, -3.07],
#        [-0.  ,  1.99,  1.99,  0.04, -0.99],
#        [-0.  ,  1.02,  2.01, -0.02, -0.01],
#        [ 0.  ,  2.99,  3.98, -0.01, -1.98],
#        [ 0.99,  3.96, -0.04,  5.04,  2.01],
#        [ 0.01, -0.  ,  1.98, -0.  , -2.  ],
#        [-1.99,  1.99,  0.  , -1.  , -0.99],
#        [ 1.02,  1.97,  1.94,  0.01, -2.98],
#        [-0.86,  1.  ,  3.06, -1.07, -2.06],
#        [ 0.99,  2.  ,  2.99, -0.  , -1.01],
#        [-1.  ,  0.01, -0.  , -0.99, -1.  ],
#        [ 1.  ,  0.99,  3.97, -0.01, -1.97],
#        [-1.  ,  2.99,  1.98, -0.  , -3.  ],
#        [ 0.97, -0.05, -0.05, -0.08, -3.03],
#        [ 0.99,  0.98,  2.  ,  0.01, -1.98],
#        [-1.  ,  3.02,  1.99, -0.  , -0.  ],
#        [ 0.98,  1.02, -0.02, -1.04, -2.  ],
#        [-0.02,  1.04,  1.97,  0.01, -0.98],
#        [ 0.99,  1.99,  2.98,  0.  , -1.99],
#        [ 2.02,  0.93, -2.01, -0.98, -1.  ],
#        [-0.01,  0.  , -0.05, -0.  , -2.98],
#        [ 0.97,  1.02,  1.94, -1.  , -2.98],
#        [ 1.01,  2.96,  4.01, -0.  , -0.99],
#        [ 0.03,  1.96,  2.03, -1.02, -2.97],
#        [ 0.02,  0.99,  0.01, -0.02, -1.97],
#        [-1.99,  2.97,  0.06, -1.  , -0.97],
#        [ 1.05,  2.  ,  1.99,  0.02, -1.  ],
#        [ 1.04,  2.02, -0.01, -0.95, -1.97],
#        [ 0.99,  3.01, -0.  ,  0.03, -1.99],
#        [ 0.97,  1.99,  1.  ,  0.05, -1.92]])

# %%
optima = np.stack(mins_found + maxs_found, axis=0)

# %%
to_label = list(optima)
label_ind = [i for i in range(len(to_label))]

# %%
edges = []
for i in range(len(optima)):
    for j in range(len(optima)):
        if i != j:
            dist = distance.euclidean(optima[i, :], optima[j, :])
            if dist < 1:  ## Distance chosen arbitrarily
                if (min(i,j), max(i,j)) not in edges:
                    edges.append((i,j))

# %%
def intermediates(p1, p2, nb_points=50):
    x_spacing = (p2[0] - p1[0]) / (nb_points + 1)
    y_spacing = (p2[1] - p1[1]) / (nb_points + 1)
    z_spacing = (p2[2] - p1[2]) / (nb_points + 1)
    a_spacing = (p2[3] - p1[3]) / (nb_points + 1)
    b_spacing = (p2[4] - p1[4]) / (nb_points + 1)

    return [[p1[0] + i * x_spacing, p1[1] +  i * y_spacing, p1[2] +  i * z_spacing, p1[3] +  i * a_spacing, p1[4] +  i * b_spacing] 
            for i in range(1, nb_points+1)]

new_data = []
for i in range(len(optima)):
    new_data.append(optima[i,:])
for edge in edges:
    pos_node_1 = optima[edge[0], :]
    pos_node_2 = optima[edge[1], :]
    new_nodes = intermediates(pos_node_1, pos_node_2)
    to_label.append(new_nodes[9])
    to_label.append(new_nodes[19])
    to_label.append(new_nodes[29])
    to_label.append(new_nodes[39])
    label_ind += [len(new_data)+9, len(new_data)+19, len(new_data)+29, len(new_data)+39]
    for node in new_nodes:
        new_data.append(np.array(node))

# %%
scaler = MinMaxScaler()
new_data_scaled = scaler.fit_transform(new_data)

# %%
mds = MDS(2, random_state=0)
mds_new_data = mds.fit_transform(new_data_scaled)

# %%
G = nx.Graph()
G.add_nodes_from([i for i in range(len(new_data))])

# %%
x = mds_new_data[:, 0]
y = mds_new_data[:, 1]

pos = {i: [x[i], y[i]] for i in range(len(new_data))}

# %%
plt.rcParams['figure.figsize'] = [25, 15]

node_sizes = [500 for _ in range(165)] + [5 for _ in range(G.number_of_nodes() - 165)]

func_val_map = {i: rastrigin(new_data[i][0], new_data[i][1], new_data[i][2], new_data[i][3], new_data[i][4]) for i in range(len(new_data))}

values = [func_val_map[node] for node in G.nodes()]

fig, ax = plt.subplots()
nx.draw(G, pos=pos, ax=ax, node_size=node_sizes, node_color=values)
# for i, opt in enumerate(optima):
#     plt.annotate(str(np.around(opt, 2)), (x[i], y[i]), xytext=(x[i]+0.03, y[i]+0.03), size=8)
limits=plt.axis('on')
plt.show()
