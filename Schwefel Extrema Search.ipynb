# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = SchwefelMax2d
funMn = SchwefelMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=20000, nb_points=10, 
               radius_percentage=0.1, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  86
# Total number of points: 1454
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.06665153,  0.03706395],
#        [-0.21445215,  0.12107331],
#        [ 0.34588267, -0.36913361],
#        ...,
#        [-0.13931822,  0.16201956],
#        [-0.14091439,  0.17729967],
#        [-0.14251021,  0.19257982]])
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Computer Modern Serif

# %%
funMx = SchwefelMax3d
funMn = SchwefelMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=30000, nb_points=10, 
               radius_percentage=0.1, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  202
# Total number of points: 2242
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.21010798, -0.29640743],
#        [ 0.09582848,  0.38255083],
#        [ 0.26675138, -0.38962126],
#        ...,
#        [ 0.474268  , -0.27419178],
#        [ 0.47187211, -0.28705872],
#        [ 0.46964375, -0.29982036]])

# %%
funMx = SchwefelMax5d
funMn = SchwefelMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.1, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9)
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  460
# Total number of points: 2964
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.34283182, -0.70272262],
#        [ 0.83497242, -0.02099215],
#        [-0.90671181, -0.36989299],
#        ...,
#        [-0.68363778, -0.54105249],
#        [-0.68325097, -0.53341941],
#        [-0.6835374 , -0.5259603 ]])
