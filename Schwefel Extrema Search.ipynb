# %%
# !pip install pynmmso
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for pynmmso: filename=pynmmso-1.0.1-py3-none-any.whl size=21370 sha256=866bff7bb400df4539d5a2fef2b44e8f729436d280b1b62eb1271e19aeddb65c
#   Stored in directory: /root/.cache/pip/wheels/3d/8d/13/53de249e3172ca783b2b737bf1e5702154f05e7e4a80602649
# Successfully built pynmmso
# ...

# %%
from extrema_search import extrema_search
from functions import *
from scipy.spatial import distance

# %%
funMx = SchwefelMax2d
funMn = SchwefelMin2d
extrema_search(funMx, funMn, number_of_fitness_evaluations=20000, nb_points=10, 
               radius_percentage=0.1, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Schwefel_2d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  95
# Total number of points: 2135
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# array([[ 0.18238903, -0.10328337],
#        [-0.40993837, -0.08719958],
#        [ 0.01551551, -0.36184946],
#        ...,
#        [ 0.04991628, -0.10203664],
#        [ 0.05915456, -0.10799917],
#        [ 0.06839289, -0.11396159]])

# %%
funMx = SchwefelMax3d
funMn = SchwefelMin3d
extrema_search(funMx, funMn, number_of_fitness_evaluations=30000, nb_points=10, 
               radius_percentage=0.1, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Schwefel_3d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  211
# Total number of points: 2715
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.18436009, -0.36734819],
#        [ 0.02855771, -0.02605775],
#        [ 0.38373998,  0.27792666],
#        ...,
#        [-0.41590031,  0.40965195],
#        [-0.42249502,  0.4023435 ],
#        [-0.42880264,  0.39565671]])

# %%
funMx = SchwefelMax5d
funMn = SchwefelMin5d
extrema_search(funMx, funMn, number_of_fitness_evaluations=50000, nb_points=10, 
               radius_percentage=0.1, nsph_points=1000, do_scaling=True, do_sphere=False, keep_percentage=0.9, 
               plot_save=True, plot_save_name='Schwefel_5d.png')
# Out:
# Looking for maxima...
# Done.
# Looking for minima...
# Done.
# Augmenting data with edge nodes...
# Total number of optima:  472
# Total number of points: 2872
# Done.
# Scaling data...
# Done.
# Perform MDS...
# Done.
# array([[-0.28467889, -0.56252212],
#        [-0.72782657,  0.15932866],
#        [ 0.51258544, -0.04483837],
#        ...,
#        [-0.566795  , -0.2631666 ],
#        [-0.58009799, -0.26794765],
#        [-0.59403022, -0.27330916]])
